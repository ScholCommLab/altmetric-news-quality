# %%
import pandas as pd

from pathlib import Path

from IPython.display import display

# %%
# data directory
data_dir = Path("../data")
collection_dir = data_dir / "collection"

# soad news sources
news_sources = pd.read_csv(data_dir / "news_sources.csv")

venue_names = news_sources["short_name"].tolist()
feed_urls = news_sources["feed_url"].tolist()

# %%
jsonl_files = list(collection_dir.glob("*.jsonl"))

# %% [markdown]
# ## Compare the returned fields for each RSS feed

# %%
dfs = {}
for f in jsonl_files:
    df = pd.read_json(f, orient="records", lines=True)
    dfs[f.name.split(".")[0]] = df
    
columns = []
sources = []
for k, df in dfs.items():
    sources.append(k)
    columns.append(df.columns)
all_vals = set([j for i in columns for j in i])

# %%
compare_dfs = pd.DataFrame(columns=sources, index=all_vals)

for source, df in dfs.items():
    for v in all_vals:
        compare_dfs.loc[v, source] = v in df.columns

# %%
compare_dfs
# Out:
#                  sciblogs popsci    nyt sciline  wired guardian
# link                 True   True   True    True   True     True
# credit              False  False   True   False  False     True
# dc_modified         False  False  False   False   True    False
# title                True   True   True    True   True     True
# published_parsed     True   True   True    True   True     True
# content             False   True   True   False  False    False
# wfw_commentrss      False  False  False    True  False    False
# media_content       False  False   True   False   True     True
# href                False  False  False   False   True    False
# author               True   True   True    True   True     True
# media_credit        False  False   True   False  False     True
# author_detail        True   True   True    True   True     True
# links                True   True   True    True   True     True
# guidislink           True   True   True    True   True     True
# comments            False  False  False    True  False    False
# id                   True   True   True    True   True     True
# published            True   True   True    True   True     True
# slash_comments      False  False  False    True  False    False
# updated_parsed      False  False  False   False  False     True
# tags                False   True   True    True   True     True
# title_detail         True   True   True    True   True     True
# media_thumbnail     False  False  False   False   True    False
# publisher           False  False  False   False   True    False
# summary_detail       True   True   True    True   True     True
# publisher_detail    False  False  False   False   True    False
# summary              True   True   True    True   True     True
# authors              True   True   True    True   True     True
# media_keywords      False  False  False   False   True    False
# updated             False  False  False   False  False     True

# %%
compare_dfs[compare_dfs.all(axis=1)]
# Out:
#                  sciblogs popsci   nyt sciline wired guardian
# link                 True   True  True    True  True     True
# title                True   True  True    True  True     True
# published_parsed     True   True  True    True  True     True
# author               True   True  True    True  True     True
# author_detail        True   True  True    True  True     True
# links                True   True  True    True  True     True
# guidislink           True   True  True    True  True     True
# id                   True   True  True    True  True     True
# published            True   True  True    True  True     True
# title_detail         True   True  True    True  True     True
# summary_detail       True   True  True    True  True     True
# summary              True   True  True    True  True     True
# authors              True   True  True    True  True     True

# %% [markdown]
# ## Processing Methodology
#
# We mainly focus on fields that are available for all news sources.
#
# - `id`
#     - is different for each news source (URL, text field, unique id)
# - `tags`
#     - guardian actually provides tags related to subcategories
#     - sciline, popsci, wired provide tags without a schema
#     - not available for sciblogs, however, we can extract a category from the fulltext
# - `summary`
#     - 5/6 provide a short summary indeed.
#     - sciblogs actually returns the full article content as HTML

# %%
dfs["sciblogs"]["summary"].iloc[4][-100:]
# Out:
# 'item"><a href="/channel/medicine" hreflang="en">Medicine</a></div>\n              </div>\n      </div>'

# %%
for k, df in dfs.items():
    print(k)
    display(df.head())
# Out:
# sciblogs
#                                                title  \
# 0  COVID-19: The Downside To More Testing Could B...
# 1        The Biology Of Why Coronavirus Is So Deadly
# 2                            The Yeast All Around Us
# 3           The 'Uplift of the Tibetan Plateau' Myth
# 4  NVX-CoV2373: Here's How The Coronavirus Vaccin...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': 'en', 'base...
# 1  {'type': 'text/plain', 'language': 'en', 'base...
# 2  {'type': 'text/plain', 'language': 'en', 'base...
# 3  {'type': 'text/plain', 'language': 'en', 'base...
# 4  {'type': 'text/plain', 'language': 'en', 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://scienceblogs.com/conversation/2020/03/...
# 1  https://scienceblogs.com/conversation/2020/04/...
# 2  https://scienceblogs.com/sb-admin/2020/05/11/y...
# 3  https://scienceblogs.com/sb-admin/2020/05/12/u...
# 4  https://scienceblogs.com/sb-admin/2020/05/27/n...
#
#                                              summary  \
# 0  <span>COVID-19: The Downside To More Testing C...
# 1  <span>The Biology Of Why Coronavirus Is So Dea...
# 2  <span>The Yeast All Around Us</span>\n\n      ...
# 3  <span>The &#039;Uplift of the Tibetan Plateau&...
# 4  <span>NVX-CoV2373: Here&#039;s How The Coronav...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': 'en', 'base'...
# 1  {'type': 'text/html', 'language': 'en', 'base'...
# 2  {'type': 'text/html', 'language': 'en', 'base'...
# 3  {'type': 'text/html', 'language': 'en', 'base'...
# 4  {'type': 'text/html', 'language': 'en', 'base'...
#
#                   published                      published_parsed  \
# 0  2020-03-31T02:25:10.000Z    [2020, 3, 31, 2, 25, 10, 1, 91, 0]
# 1  2020-04-02T18:02:27.000Z     [2020, 4, 2, 18, 2, 27, 3, 93, 0]
# 2  2020-05-11T15:54:57.000Z  [2020, 5, 11, 15, 54, 57, 0, 132, 0]
# 3  2020-05-12T14:40:03.000Z   [2020, 5, 12, 14, 40, 3, 1, 133, 0]
# 4  2020-05-27T14:18:04.000Z   [2020, 5, 27, 14, 18, 4, 2, 148, 0]
#
#                           authors            author  \
# 0  [{'name': 'The Conversation'}]  The Conversation
# 1  [{'name': 'The Conversation'}]  The Conversation
# 2          [{'name': 'sb admin'}]          sb admin
# 3          [{'name': 'sb admin'}]          sb admin
# 4          [{'name': 'sb admin'}]          sb admin
#
#                   author_detail                                  id  \
# 0  {'name': 'The Conversation'}  151446 at https://scienceblogs.com
# 1  {'name': 'The Conversation'}  151447 at https://scienceblogs.com
# 2          {'name': 'sb admin'}  151448 at https://scienceblogs.com
# 3          {'name': 'sb admin'}  151449 at https://scienceblogs.com
# 4          {'name': 'sb admin'}  151450 at https://scienceblogs.com
#
#    guidislink
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# popsci
#                                                title  \
# 0  Best document scanner: Wireless, handheld, and...
# 1  Why are we still disinfecting surfaces to stop...
# 2  Best laser printer: For the home or for your o...
# 3  This Airbus prototype could deploy drones from...
# 4  No cell service? These are the best offline apps.
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://www.popsci.com/story/reviews/best-docu...
# 1  https://www.popsci.com/story/health/covid-19-s...
# 2  https://www.popsci.com/story/reviews/best-lase...
# 3  https://www.popsci.com/story/technology/airbus...
# 4  https://www.popsci.com/story/diy/best-offline-...
#
#                                              summary  \
# 0  Buy the best document scanner for your office ...
# 1  The question isn't if COVID-19 can spread from...
# 2  Are you looking for the best laser printer for...
# 3  Here's why militaries are interested in airpla...
# 4  These apps are the best in the biz at offline ...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                                   id  guidislink  \
# 0  https://www.popsci.com/story/reviews/best-docu...       False
# 1  https://www.popsci.com/story/health/covid-19-s...       False
# 2  https://www.popsci.com/story/reviews/best-lase...       False
# 3  https://www.popsci.com/story/technology/airbus...       False
# 4  https://www.popsci.com/story/diy/best-offline-...       False
#
#                                           authors  \
# 0              [{'name': 'PopSci Commerce Team'}]
# 1  [{'name': 'By Hassan Vally/The Conversation'}]
# 2              [{'name': 'PopSci Commerce Team'}]
# 3                [{'name': 'Kelsey D. Atherton'}]
# 4                       [{'name': 'David Nield'}]
#
#                              author  \
# 0              PopSci Commerce Team
# 1  By Hassan Vally/The Conversation
# 2              PopSci Commerce Team
# 3                Kelsey D. Atherton
# 4                       David Nield
#
#                                   author_detail  \
# 0              {'name': 'PopSci Commerce Team'}
# 1  {'name': 'By Hassan Vally/The Conversation'}
# 2              {'name': 'PopSci Commerce Team'}
# 3                {'name': 'Kelsey D. Atherton'}
# 4                       {'name': 'David Nield'}
#
#                                                 tags  \
# 0  [{'term': 'Reviews', 'scheme': None, 'label': ...
# 1  [{'term': 'Health', 'scheme': None, 'label': N...
# 2  [{'term': 'Reviews', 'scheme': None, 'label': ...
# 3  [{'term': 'Technology', 'scheme': None, 'label...
# 4   [{'term': 'Diy', 'scheme': None, 'label': None}]
#
#                   published                     published_parsed  \
# 0  2021-02-24T17:59:00.000Z   [2021, 2, 24, 17, 59, 0, 2, 55, 0]
# 1  2021-02-24T19:23:42.000Z  [2021, 2, 24, 19, 23, 42, 2, 55, 0]
# 2  2021-02-24T19:59:00.000Z   [2021, 2, 24, 19, 59, 0, 2, 55, 0]
# 3  2021-02-24T21:00:00.000Z    [2021, 2, 24, 21, 0, 0, 2, 55, 0]
# 4  2021-02-25T13:00:00.000Z    [2021, 2, 25, 13, 0, 0, 3, 56, 0]
#
#                                              content
# 0  [{'type': 'text/html', 'language': None, 'base...
# 1  [{'type': 'text/html', 'language': None, 'base...
# 2  [{'type': 'text/html', 'language': None, 'base...
# 3  [{'type': 'text/html', 'language': None, 'base...
# 4  [{'type': 'text/html', 'language': None, 'base...
# nyt
#                                                title  \
# 0  Octopuses Have a Secret Sense to Keep Their 8 ...
# 1                               Things To Do At Home
# 2  Texas Blackouts Point to Coast-to-Coast Crises...
# 3  Seven Hundred Leagues Beneath Titan’s Methane ...
# 4  She Beat Cancer at 10. Now She'll Join SpaceX'...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://www.nytimes.com/2021/02/20/science/oct...
# 1  https://www.nytimes.com/2021/02/20/at-home/thi...
# 2  https://www.nytimes.com/2021/02/20/climate/uni...
# 3  https://www.nytimes.com/2021/02/21/science/sat...
# 4  https://www.nytimes.com/2021/02/22/science/spa...
#
#                                                   id  guidislink  \
# 0  https://www.nytimes.com/2021/02/20/science/oct...       False
# 1  https://www.nytimes.com/2021/02/20/at-home/thi...       False
# 2  https://www.nytimes.com/2021/02/20/climate/uni...       False
# 3  https://www.nytimes.com/2021/02/21/science/sat...       False
# 4  https://www.nytimes.com/2021/02/22/science/spa...       False
#
#                                              summary  \
# 0  Even when an octopus can’t see light with its ...
# 1  This week, celebrate the life of Malcolm X, br...
# 2  Continent-spanning storms triggered blackouts ...
# 3  Mars, Shmars; this voyager is looking forward ...
# 4  St. Jude Hospital and Jared Isaacman, a billio...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                              authors  \
# 0                         [{'name': 'Richard Sima'}]
# 1         [{'name': 'Emma Grillo and Danya Issawi'}]
# 2  [{'name': 'Christopher Flavelle, Brad Plumer a...
# 3                       [{'name': 'Dennis Overbye'}]
# 4                        [{'name': 'Kenneth Chang'}]
#
#                                               author  \
# 0                                       Richard Sima
# 1                       Emma Grillo and Danya Issawi
# 2  Christopher Flavelle, Brad Plumer and Hiroko T...
# 3                                     Dennis Overbye
# 4                                      Kenneth Chang
#
#                                        author_detail  \
# 0                           {'name': 'Richard Sima'}
# 1           {'name': 'Emma Grillo and Danya Issawi'}
# 2  {'name': 'Christopher Flavelle, Brad Plumer an...
# 3                         {'name': 'Dennis Overbye'}
# 4                          {'name': 'Kenneth Chang'}
#
#                   published                     published_parsed  \
# 0  2021-02-20T10:00:13.000Z   [2021, 2, 20, 10, 0, 13, 5, 51, 0]
# 1  2021-02-21T04:59:05.000Z    [2021, 2, 21, 4, 59, 5, 6, 52, 0]
# 2  2021-02-21T17:44:08.000Z   [2021, 2, 21, 17, 44, 8, 6, 52, 0]
# 3  2021-02-21T22:21:34.000Z  [2021, 2, 21, 22, 21, 34, 6, 52, 0]
# 4  2021-02-22T18:10:23.000Z  [2021, 2, 22, 18, 10, 23, 0, 53, 0]
#
#                                                 tags  \
# 0  [{'term': 'Light', 'scheme': 'http://www.nytim...
# 1  [{'term': 'Quarantine (Life and Culture)', 'sc...
# 2  [{'term': 'Power Failures and Blackouts', 'sch...
# 3  [{'term': 'Space and Astronomy', 'scheme': 'ht...
# 4  [{'term': 'Isaacman, Jared (1983- )', 'scheme'...
#
#                                        media_content  \
# 0                                               None
# 1  [{'height': '151', 'medium': 'image', 'url': '...
# 2  [{'height': '151', 'medium': 'image', 'url': '...
# 3  [{'height': '151', 'medium': 'image', 'url': '...
# 4                                               None
#
#                                         media_credit  \
# 0                                               None
# 1                     [{'content': 'Miguel Porlan'}]
# 2           [{'content': 'Joe Raedle/Getty Images'}]
# 3  [{'content': 'NASA/JPL-Caltech/Space Science I...
# 4                                               None
#
#                                      credit  \
# 0                                      None
# 1                             Miguel Porlan
# 2                   Joe Raedle/Getty Images
# 3  NASA/JPL-Caltech/Space Science Institute
# 4                                      None
#
#                                              content
# 0                                               None
# 1                                               None
# 2  [{'type': 'text/plain', 'language': None, 'bas...
# 3                                               None
# 4                                               None
# sciline
#                                                title  \
# 0               Roundup may harm honeybee gut health
# 1  Terra-farming: A possible step toward growing ...
# 2                               Death of a sourdough
# 3  A little blue pill that protects you from HIV ...
# 4  Novel Science: Steampunk and the history of pr...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://scienceline.org/2021/01/roundup-may-ha...
# 1  https://scienceline.org/2021/01/terra-farming-...
# 2  https://scienceline.org/2021/01/death-of-a-sou...
# 3  https://scienceline.org/2021/01/a-little-blue-...
# 4  https://scienceline.org/2021/02/novel-science-...
#
#                                             comments  \
# 0  https://scienceline.org/2021/01/roundup-may-ha...
# 1  https://scienceline.org/2021/01/terra-farming-...
# 2  https://scienceline.org/2021/01/death-of-a-sou...
# 3  https://scienceline.org/2021/01/a-little-blue-...
# 4  https://scienceline.org/2021/02/novel-science-...
#
#                          authors           author  \
# 0  [{'name': 'Casey Crownhart'}]  Casey Crownhart
# 1     [{'name': 'Jackie Appel'}]     Jackie Appel
# 2   [{'name': 'Ethan Freedman'}]   Ethan Freedman
# 3       [{'name': 'Karen Kwon'}]       Karen Kwon
# 4  [{'name': 'Joanna Thompson'}]  Joanna Thompson
#
#                  author_detail                 published  \
# 0  {'name': 'Casey Crownhart'}  2021-01-25T13:00:45.000Z
# 1     {'name': 'Jackie Appel'}  2021-01-27T13:00:19.000Z
# 2   {'name': 'Ethan Freedman'}  2021-01-28T17:00:47.000Z
# 3       {'name': 'Karen Kwon'}  2021-01-29T13:00:39.000Z
# 4  {'name': 'Joanna Thompson'}  2021-02-01T13:00:05.000Z
#
#                      published_parsed  \
# 0  [2021, 1, 25, 13, 0, 45, 0, 25, 0]
# 1  [2021, 1, 27, 13, 0, 19, 2, 27, 0]
# 2  [2021, 1, 28, 17, 0, 47, 3, 28, 0]
# 3  [2021, 1, 29, 13, 0, 39, 4, 29, 0]
# 4    [2021, 2, 1, 13, 0, 5, 0, 32, 0]
#
#                                                 tags  \
# 0  [{'term': 'Environment', 'scheme': None, 'labe...
# 1  [{'term': 'Space, Physics, and Math', 'scheme'...
# 2  [{'term': 'Audio', 'scheme': None, 'label': No...
# 3  [{'term': 'Health', 'scheme': None, 'label': N...
# 4  [{'term': 'Novel Science', 'scheme': None, 'la...
#
#                                  id  guidislink  \
# 0  https://scienceline.org/?p=32739       False
# 1  https://scienceline.org/?p=32916       False
# 2  https://scienceline.org/?p=32943       False
# 3  https://scienceline.org/?p=32934       False
# 4  https://scienceline.org/?p=32975       False
#
#                                              summary  \
# 0  <p>The popular weed killer could impair honeyb...
# 1  <p>Scientists recently developed a substance t...
# 2  <p>How a neglected sourdough starter can go fr...
# 3  <p>PrEP is close to 99% effective in preventin...
# 4  <p>Reimagining the past, now with 40% more gea...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                       wfw_commentrss  slash_comments
# 0  https://scienceline.org/2021/01/roundup-may-ha...               0
# 1  https://scienceline.org/2021/01/terra-farming-...               4
# 2  https://scienceline.org/2021/01/death-of-a-sou...               0
# 3  https://scienceline.org/2021/01/a-little-blue-...               0
# 4  https://scienceline.org/2021/02/novel-science-...               0
# wired
#                                                title  \
# 0  The AI Research Paper Was Real. The ‘Coauthor’...
# 1  As Coronavirus Variants Spread, the US Struggl...
# 2  Storm Delays for Vaccines, Expanded Sequencing...
# 3  Why France’s New Tech ‘Repairability Index’ Is...
# 4  Can Hamburger Buns Save Your Pipes from Freezing?
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://www.wired.com/story/ai-research-paper-...
# 1  https://www.wired.com/story/as-coronavirus-var...
# 2  https://www.wired.com/story/storm-delays-vacci...
# 3  https://www.wired.com/story/frances-new-tech-r...
# 4  https://www.wired.com/story/can-hamburger-buns...
#
#                          id  guidislink                 published  \
# 0  602e965d0498dc83a227e612       False  2021-02-19T12:00:00.000Z
# 1  602d75c05b23975cb700ff5e       False  2021-02-19T12:00:00.000Z
# 2  602fd0a644e48281d964ca29       False  2021-02-19T20:09:42.000Z
# 3  602c39295b23975cb700ff59       False  2021-02-20T13:00:00.000Z
# 4  60302c7ef5a63ce68f38a76f       False  2021-02-20T14:00:00.000Z
#
#                      published_parsed media_content  \
# 0   [2021, 2, 19, 12, 0, 0, 4, 50, 0]          [{}]
# 1   [2021, 2, 19, 12, 0, 0, 4, 50, 0]          [{}]
# 2  [2021, 2, 19, 20, 9, 42, 4, 50, 0]          [{}]
# 3   [2021, 2, 20, 13, 0, 0, 5, 51, 0]          [{}]
# 4   [2021, 2, 20, 14, 0, 0, 5, 51, 0]          [{}]
#
#                                              summary  ...  \
# 0  An IBM researcher found his name on two papers...  ...
# 1  The nation is a sequencing superpower. But wit...  ...
# 2  Catch up on the most important updates from th...  ...
# 3                    Liberté, égalité, reparabilité.  ...
# 4  Water expands when it freezes, and that’s bad ...  ...
#
#                                                 tags  \
# 0  [{'term': 'Business', 'scheme': None, 'label':...
# 1  [{'term': 'Science', 'scheme': None, 'label': ...
# 2  [{'term': 'Science', 'scheme': None, 'label': ...
# 3  [{'term': 'Science', 'scheme': None, 'label': ...
# 4  [{'term': 'Science', 'scheme': None, 'label': ...
#
#                                       media_keywords  \
# 0  science, academia, research, artificial intell...
# 1  coronavirus, COVID-19, Genomics, surveillance,...
# 2                    COVID-19, coronavirus, vaccines
# 3  Climate Desk, recycling, trash, electronics, m...
# 4  Dot Physics, temperature, water, extreme weath...
#
#                        authors         author              author_detail  \
# 0    [{'name': 'Will Knight'}]    Will Knight    {'name': 'Will Knight'}
# 1  [{'name': 'Megan Molteni'}]  Megan Molteni  {'name': 'Megan Molteni'}
# 2    [{'name': 'Eve Sneider'}]    Eve Sneider    {'name': 'Eve Sneider'}
# 3   [{'name': 'Maddie Stone'}]   Maddie Stone   {'name': 'Maddie Stone'}
# 4   [{'name': 'Rhett Allain'}]   Rhett Allain   {'name': 'Rhett Allain'}
#
#                        dc_modified   publisher        publisher_detail  \
# 0  Sat, 20 Feb 2021 18:52:44 +0000  Condé Nast  {'name': 'Condé Nast'}
# 1  Mon, 22 Feb 2021 16:54:32 +0000  Condé Nast  {'name': 'Condé Nast'}
# 2  Fri, 19 Feb 2021 22:11:49 +0000  Condé Nast  {'name': 'Condé Nast'}
# 3  Fri, 19 Feb 2021 15:33:35 +0000  Condé Nast  {'name': 'Condé Nast'}
# 4  Sat, 20 Feb 2021 05:48:31 +0000  Condé Nast  {'name': 'Condé Nast'}
#
#                                      media_thumbnail href
# 0  [{'url': 'https://media.wired.com/photos/602f1...
# 1  [{'url': 'https://media.wired.com/photos/602ef...
# 2  [{'url': 'https://media.wired.com/photos/602fd...
# 3  [{'url': 'https://media.wired.com/photos/602fd...
# 4  [{'url': 'https://media.wired.com/photos/60305...
#
# [5 rows x 21 columns]
# guardian
#                                                title  \
# 0                Can you solve it? Think of a number
# 1                Did you solve it? Think of a number
# 2               Covid-19: love in lockdown – podcast
# 3  New Covid variant with potentially worrying mu...
# 4    Covid-19: why mix and match vaccines? – podcast
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://www.theguardian.com/science/2021/feb/0...
# 1  https://www.theguardian.com/science/2021/feb/0...
# 2  https://www.theguardian.com/science/audio/2021...
# 3  https://www.theguardian.com/world/2021/feb/15/...
# 4  https://www.theguardian.com/science/audio/2021...
#
#                                              summary  \
# 0  <p>A new twist on the all time classic maths t...
# 1  <p>The solution to today’s Q&amp;A puzzle</p><...
# 2  <p>Valentine’s Day is fast approaching, and fo...
# 3  <p>Researchers say 32 cases of B1525 in Britai...
# 4  <p>The Com-Cov trial run by the Oxford Vaccine...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                                 tags  \
# 0  [{'term': 'Mathematics', 'scheme': 'https://ww...
# 1  [{'term': 'Mathematics', 'scheme': 'https://ww...
# 2  [{'term': 'Science', 'scheme': 'https://www.th...
# 3  [{'term': 'Coronavirus', 'scheme': 'https://ww...
# 4  [{'term': 'Science', 'scheme': 'https://www.th...
#
#                   published                     published_parsed  \
# 0  2021-02-08T07:12:18.000Z    [2021, 2, 8, 7, 12, 18, 0, 39, 0]
# 1  2021-02-08T17:00:48.000Z    [2021, 2, 8, 17, 0, 48, 0, 39, 0]
# 2  2021-02-11T09:40:35.000Z   [2021, 2, 11, 9, 40, 35, 3, 42, 0]
# 3  2021-02-15T16:48:44.000Z  [2021, 2, 15, 16, 48, 44, 0, 46, 0]
# 4  2021-02-16T05:00:41.000Z    [2021, 2, 16, 5, 0, 41, 1, 47, 0]
#
#                                                   id  guidislink  \
# 0  https://www.theguardian.com/science/2021/feb/0...       False
# 1  https://www.theguardian.com/science/2021/feb/0...       False
# 2  https://www.theguardian.com/science/audio/2021...       False
# 3  https://www.theguardian.com/world/2021/feb/15/...       False
# 4  https://www.theguardian.com/science/audio/2021...       False
#
#                                        media_content  \
# 0  [{'width': '140', 'url': 'https://i.guim.co.uk...
# 1  [{'width': '140', 'url': 'https://i.guim.co.uk...
# 2  [{'width': '140', 'url': 'https://i.guim.co.uk...
# 3  [{'width': '140', 'url': 'https://i.guim.co.uk...
# 4  [{'width': '140', 'url': 'https://i.guim.co.uk...
#
#                                         media_credit  \
# 0  [{'scheme': 'urn:ebu', 'content': 'Photograph:...
# 1  [{'scheme': 'urn:ebu', 'content': 'Photograph:...
# 2  [{'scheme': 'urn:ebu', 'content': 'Photograph:...
# 3  [{'scheme': 'urn:ebu', 'content': 'Photograph:...
# 4  [{'scheme': 'urn:ebu', 'content': 'Photograph:...
#
#                                       credit  \
# 0                        Photograph: ITV/REX
# 1             Photograph: Bernat Armangue/AP
# 2  Photograph: Action Press/REX/Shutterstock
# 3             Photograph: Ammar Awad/Reuters
# 4               Photograph: Thomas Samson/AP
#
#                                              authors  \
# 0                          [{'name': 'Alex Bellos'}]
# 1                          [{'name': 'Alex Bellos'}]
# 2  [{'name': 'Presented by Linda Geddes and produ...
# 3   [{'name': 'Nicola Davis Science correspondent'}]
# 4  [{'name': 'Presented by Sarah Boseley and prod...
#
#                                               author  \
# 0                                        Alex Bellos
# 1                                        Alex Bellos
# 2  Presented by Linda Geddes and produced by Made...
# 3                 Nicola Davis Science correspondent
# 4  Presented by Sarah Boseley and produced by Tif...
#
#                                        author_detail               updated  \
# 0                            {'name': 'Alex Bellos'}  2021-02-08T07:12:18Z
# 1                            {'name': 'Alex Bellos'}  2021-02-08T17:00:48Z
# 2  {'name': 'Presented by Linda Geddes and produc...  2021-02-11T09:40:35Z
# 3     {'name': 'Nicola Davis Science correspondent'}  2021-02-15T16:48:44Z
# 4  {'name': 'Presented by Sarah Boseley and produ...  2021-02-16T05:00:41Z
#
#                         updated_parsed
# 0    [2021, 2, 8, 7, 12, 18, 0, 39, 0]
# 1    [2021, 2, 8, 17, 0, 48, 0, 39, 0]
# 2   [2021, 2, 11, 9, 40, 35, 3, 42, 0]
# 3  [2021, 2, 15, 16, 48, 44, 0, 46, 0]
# 4    [2021, 2, 16, 5, 0, 41, 1, 47, 0]

# %%
for k, df in dfs.items():
    print(k)
    try:
        print(df["tags"].iloc[0])
    except:
        pass
    print("==========")
# Out:
# sciblogs
# ==========
# popsci
# [{'term': 'Reviews', 'scheme': None, 'label': None}]
# ==========
# nyt
# [{'term': 'Light', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}, {'term': 'Research', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}, {'term': 'Octopus', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}, {'term': 'Animal Behavior', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}, {'term': 'Animal Cognition', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}, {'term': 'Journal of Experimental Biology', 'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org', 'label': None}, {'term': 'your-feed-animals', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}, {'term': 'your-feed-science', 'scheme': 'http://www.nytimes.com/namespaces/keywords/des', 'label': None}]
# ==========
# sciline
# [{'term': 'Environment', 'scheme': None, 'label': None}, {'term': 'animals', 'scheme': None, 'label': None}, {'term': 'bees', 'scheme': None, 'label': None}, {'term': 'biology', 'scheme': None, 'label': None}, {'term': 'chemistry', 'scheme': None, 'label': None}, {'term': 'climate change', 'scheme': None, 'label': None}, {'term': 'conservation', 'scheme': None, 'label': None}, {'term': 'ecology', 'scheme': None, 'label': None}, {'term': 'food', 'scheme': None, 'label': None}, {'term': 'honeybees', 'scheme': None, 'label': None}, {'term': 'insects', 'scheme': None, 'label': None}, {'term': 'plants', 'scheme': None, 'label': None}]
# ==========
# wired
# [{'term': 'Business', 'scheme': None, 'label': None}, {'term': 'Business / Artificial Intelligence', 'scheme': None, 'label': None}, {'term': 'Science', 'scheme': None, 'label': None}, {'term': 'science', 'scheme': None, 'label': None}, {'term': 'academia', 'scheme': None, 'label': None}, {'term': 'research', 'scheme': None, 'label': None}, {'term': 'artificial intelligence', 'scheme': None, 'label': None}, {'term': 'Ghost Writer', 'scheme': None, 'label': None}]
# ==========
# guardian
# [{'term': 'Mathematics', 'scheme': 'https://www.theguardian.com/education/mathematics', 'label': None}, {'term': 'Mathematics', 'scheme': 'https://www.theguardian.com/science/mathematics', 'label': None}, {'term': 'Education', 'scheme': 'https://www.theguardian.com/education/education', 'label': None}, {'term': 'Science', 'scheme': 'https://www.theguardian.com/science/science', 'label': None}]
# ==========
